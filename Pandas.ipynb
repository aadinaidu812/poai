# %% [markdown]
# <a href="https://colab.research.google.com/github/aadinaidu812/poai/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
s = pd.Series(dtype="int32")
s
# Out:
# Series([], dtype: int32)

# %%
data = np.array(['a','b','c','d'])
s=pd.Series(data)
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
s = pd.Series(data, index=[100,101,102,103])
s
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
data = {'a': 0, 'b':1,'c':2}
mylist=[5.4,6.1,1.7,99.8]
s = pd.Series(data)
s['b']
myseries1=pd.Series(data=mylist)
print(myseries1)
# Out:
# 0     5.4
# 1     6.1
# 2     1.7
# 3    99.8
# dtype: float64

# %%
mylabels = ['first','second','third','fourth']
myseries3 = pd.Series(index = mylabels,data=mylist)
myseries3
# Out:
# first      5.4
# second     6.1
# third      1.7
# fourth    99.8
# dtype: float64

# %%
myseries4 = pd.Series(mylist,mylabels)
myseries4
# Out:
# first      5.4
# second     6.1
# third      1.7
# fourth    99.8
# dtype: float64

# %%
myseries5 =pd.Series([5.5,1.1,8.8,1.6],['first','third','fourth','fifth'])
myseries5
# Out:
# first     5.5
# third     1.1
# fourth    8.8
# fifth     1.6
# dtype: float64

# %%
myseries5+myseries4
# Out:
# fifth       NaN
# first      10.9
# fourth    108.6
# second      NaN
# third       2.8
# dtype: float64

# %%
df2 = pd.DataFrame(np.random.randn(5,5))
df2
# Out:
#           0         1         2         3         4
# 0 -1.300263  1.135285 -0.843948  0.003220  0.488198
# 1 -2.039155 -0.141265  0.138723 -0.354705 -0.122352
# 2  0.144520 -0.185466 -1.339448  0.011621 -0.215930
# 3  0.482998 -1.055132 -0.904661  0.509234  0.302660
# 4  0.110346  0.942288  0.562231 -0.485186  0.663974

# %%
df3 = pd.DataFrame(np.random.randn(5,5), index = ['first row', 'secondrow', 'third row', 'fourth row', 'fifth row'],
columns=['first col', 'second col', 'third col', 'fourth col','fifthcol'])
df3
# Out:
#             first col  second col  third col  fourth col  fifthcol
# first row    1.412109   -1.441216   0.193412   -0.363149  2.021719
# secondrow    1.199578   -0.070583   2.319480    0.332907 -0.482868
# third row   -0.764905   -0.431051  -0.860522    0.518586 -0.504149
# fourth row  -1.071243    0.045595  -0.841524    0.563959  0.745545
# fifth row   -0.741447    1.117582  -0.102321    1.360181 -0.583854

# %%
print(df3['second col'])
print('')
df3[['third col','first col']]
# Out:
# first row    -1.441216
# secondrow    -0.070583
# third row    -0.431051
# fourth row    0.045595
# fifth row     1.117582
# Name: second col, dtype: float64
#             third col  first col
# first row    0.193412   1.412109
# secondrow    2.319480   1.199578
# third row   -0.860522  -0.764905
# fourth row  -0.841524  -1.071243
# fifth row   -0.102321  -0.741447
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6702651018485645447 = autoviz.get_df('df_6702651018485645447')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
# ...

# %%
df3.loc['fourth row']
# Out:
# first col    -1.071243
# second col    0.045595
# third col    -0.841524
# fourth col    0.563959
# fifthcol      0.745545
# Name: fourth row, dtype: float64

# %%
df3.loc[['fourth row','first row'],['second col','third col']]
# Out:
#             second col  third col
# fourth row    0.045595  -0.841524
# first row    -1.441216   0.193412

# %%
df3[df3>0]
# Out:
#             first col  second col  third col  fourth col  fifthcol
# first row    1.412109         NaN   0.193412         NaN  2.021719
# secondrow    1.199578         NaN   2.319480    0.332907       NaN
# third row         NaN         NaN        NaN    0.518586       NaN
# fourth row        NaN    0.045595        NaN    0.563959  0.745545
# fifth row         NaN    1.117582        NaN    1.360181       NaN

# %%
df5 = pd.DataFrame(np.random.randn(6,6), index = ['index', 'first row', 'secondrow', 'third row', 'fourth row', 'fifth row'],
columns=['first col', 'second col', 'third col', 'fourth col','fifthcol',"sixthcol"])
df5
# Out:
#             first col  second col  third col  fourth col  fifthcol  sixthcol
# index       -0.784644   -1.028543   1.016958   -0.695716 -0.266656 -0.912365
# first row    0.457937    0.255042   1.179716    0.700089 -1.244055 -0.339182
# secondrow    1.031542    0.102205   0.076432   -0.461274 -0.420028 -0.462667
# third row    0.557226    0.904056  -0.150607   -0.982681  0.091693 -0.582166
# fourth row  -1.312133    1.640886   1.104374   -0.795005 -0.272403  0.416513
# fifth row    0.042412   -0.550968  -0.566043    0.986982 -1.674208 -0.223349

# %%
df5.reset_index(inplace=True)
df5
# Out:
#         index  first col  second col  third col  fourth col  fifthcol  \
# 0       index  -0.784644   -1.028543   1.016958   -0.695716 -0.266656
# 1   first row   0.457937    0.255042   1.179716    0.700089 -1.244055
# 2   secondrow   1.031542    0.102205   0.076432   -0.461274 -0.420028
# 3   third row   0.557226    0.904056  -0.150607   -0.982681  0.091693
# 4  fourth row  -1.312133    1.640886   1.104374   -0.795005 -0.272403
# 5   fifth row   0.042412   -0.550968  -0.566043    0.986982 -1.674208
#
#    sixthcol
# 0 -0.912365
# 1 -0.339182
# 2 -0.462667
# 3 -0.582166
# 4  0.416513
# 5 -0.223349

# %%
df7 = pd.DataFrame({"customer":['101','102','103','104'],'category': ['cat2','cat2','cat1','cat3'],'important': ['yes','no','yes','yes'],'sales': [123,52,214,663]},index=[0,1,2,3])
df8 = pd.DataFrame({"customer":['101','103','104','105'],'color': ['yellow','green','green','blue'],'distance': [12,9,44,21],'sales': [123,214,663,331]},index=[4,5,6,7])
pd.concat([df7,df8],axis=0,sort=False)
# Out:
#   customer category important  sales   color  distance
# 0      101     cat2       yes    123     NaN       NaN
# 1      102     cat2        no     52     NaN       NaN
# 2      103     cat1       yes    214     NaN       NaN
# 3      104     cat3       yes    663     NaN       NaN
# 4      101      NaN       NaN    123  yellow      12.0
# 5      103      NaN       NaN    214   green       9.0
# 6      104      NaN       NaN    663   green      44.0
# 7      105      NaN       NaN    331    blue      21.0

# %%
pd.concat([df7,df8],axis=0,sort=True)
pd.concat([df7,df8],axis=1,sort=False)
pd.merge(df7,df8,how='outer',on='customer')
pd.merge(df7,df8,how='inner',on='customer')
pd.merge(df7,df8,how='right',on='customer')
df9 = pd.DataFrame({'Q1': [101,102,103],
'Q2': [201,202,203]},
index = ['I0','I1','I2'])
df10 = pd.DataFrame({'Q3': [301,302,303],'Q4': [401,402,403]},
index=['I0','I2','I3'])
df11 = df8[['distance','sales']]
mydict = {'customer': ['Customer 1','Customer1','Customer2','Customer2','Customer3','Customer3'],
'product1': [1.1,2.1,3.8,4.2,5.5,6.9],
'product2': [8.2,9.1,11.1,5.2,44.66,983]}
df6 = pd.DataFrame(mydict, index = ['Purchase 1','Purchase2','Purchase 3','Purchase 4','Purchase 5','Purchase 6'])
df6
# Out:
#               customer  product1  product2
# Purchase 1  Customer 1       1.1      8.20
# Purchase2    Customer1       2.1      9.10
# Purchase 3   Customer2       3.8     11.10
# Purchase 4   Customer2       4.2      5.20
# Purchase 5   Customer3       5.5     44.66
# Purchase 6   Customer3       6.9    983.00

# %%
df8.to_excel('df8.xlsx', index = False, sheet_name='first sheet')
newer_df8 = pd.read_excel('df8.xlsx', sheet_name='first sheet',index_col=1)
newer_df8
# Out:
#         customer  distance  sales
# color
# yellow       101        12    123
# green        103         9    214
# green        104        44    663
# blue         105        21    331
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_9220071198313236548 = autoviz.get_df('df_9220071198313236548')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_9220071198313236548, *['customer'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# ...

# %%
df = pd.read_csv('df8.csv')
df = df.drop(df.columns[0], axis = 1)
print((df.index))
df_new = pd.DataFrame(df, index = [1,2,3,0], columns=['customer','distance','sales'])
df_new, df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-9b3e384710b3> in <cell line: 1>()
# ----> 1 df = pd.read_csv('df8.csv')
#       2 df = df.drop(df.columns[0], axis = 1)
#       3 print((df.index))
#       4 df_new = pd.DataFrame(df, index = [1,2,3,0], columns=['customer','distance','sales'])
#       5 df_new, df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...
